# %% [markdown]
# # Download Datasets
#
# This notebook demonstrates how to download and use datasets from PerturbLab's resource registry.
#
# ## Features
# - Automatic caching in `~/.cache/perturblab/`
# - Support for scPerturb benchmark datasets (55+ datasets)
# - Gene Ontology (GO) files
# - Progress tracking and resume support

# %%
from perturblab.data.resources import load_dataset, get_dataset, list_datasets
import anndata as ad

# List all available datasets
print("Available datasets:")
datasets = list_datasets()
print(f"Total: {len(datasets)} datasets")
print("\nFirst 10 datasets:")
for ds in datasets[:10]:
    print(f"  - {ds}")
# Out:
# Available datasets:
# Total: 58 datasets
#
# First 10 datasets:
#   - go/gene2go_gears
#   - go/go_basic
#   - go/go_full
#   - scperturb/adamson_2016_10x001
#   - scperturb/adamson_2016_10x005
#   - scperturb/adamson_2016_10x010
#   - scperturb/aissa_2021
#   - scperturb/chang_2021
#   - scperturb/cui_2023
#   - scperturb/datlinger_2017

# %% [markdown]
# ## Download scPerturb Benchmark Dataset

# %%
# Download a scPerturb dataset (automatically cached)
# First call downloads, subsequent calls use cache
h5ad_path = load_dataset('scperturb/norman_2019')
print(f"Dataset downloaded to: {h5ad_path}")

# Load into AnnData
adata = ad.read_h5ad(h5ad_path)
print(f"\nDataset shape: {adata.shape}")
print(f"Genes: {adata.n_vars}, Cells: {adata.n_obs}")
print(f"\nObservations columns: {list(adata.obs.columns[:5])}")
print(f"Variables columns: {list(adata.var.columns[:5])}")
# Out:
# [perturblab] [INFO] Cache miss: norman_2019.h5ad (is_directory=False), creating...
# [perturblab] [INFO] Downloading remote resource 'norman_2019'...
# [perturblab] [INFO] Downloading: https://zenodo.org/record/13350497/files/NormanWeissman2019.h5ad?download=1
# [perturblab] [INFO] Target: /home/wzq/.cache/perturblab/auto/.tmp_norman_2019.h5ad_ehl30_je
# [perturblab] [ERROR] Failed to cache norman_2019.h5ad: Failed to download from https://zenodo.org/record/13350497/files/NormanWeissman2019.h5ad?download=1: 404 Client Error: NOT FOUND for url: https://zenodo.org/records/13350497/files/NormanWeissman2019.h5ad
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Code/Projects/PerturbLab/perturblab/io/download/_http.py:149, in HTTPDownloader.download(url, target_path, resume, show_progress, chunk_size, timeout, max_retries, backoff_factor)
#     143 response = session.get(
#     144     url,
#     145     headers=headers,
#     146     stream=True,
#     147     timeout=timeout,
#     148 )
# --> 149 response.raise_for_status()
#     151 # Get total size
#
# File ~/Code/Projects/PerturbLab/.venv/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: NOT FOUND for url: https://zenodo.org/records/13350497/files/NormanWeissman2019.h5ad
#
# During handling of the above exception, another exception occurred:
#
# DownloadError                             Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Download a scPerturb dataset (automatically cached)
#       2 # First call downloads, subsequent calls use cache
# ----> 3 h5ad_path = load_dataset('scperturb/norman_2019')
#       4 print(f"Dataset downloaded to: {h5ad_path}")
#       6 # Load into AnnData
#
# File ~/Code/Projects/PerturbLab/perturblab/data/resources/__init__.py:338, in load_dataset(path)
#     335 resource = get_dataset(path)
#     337 # All resources should return Path via .load()
# --> 338 return resource.load()
#
# File ~/Code/Projects/PerturbLab/perturblab/core/resource.py:202, in Resource.load(self)
#     183 def load(self) -> T:
#     184     """
#     185     Load the resource data (alias for .data property).
#     186
#    (...)    200     >>> adata = resource.data  # Property style
#     201     """
# --> 202     return self.data
#
# File ~/Code/Projects/PerturbLab/perturblab/core/resource.py:172, in Resource.data(self)
#     152 """
#     153 Get the data object in memory (Lazy Load).
#     154
#    (...)    169 >>> assert adata is adata2  # Same object
#     170 """
#     171 if self._data is None:
# --> 172     target_path = self.path  # Ensures file exists locally
#     174     logger.info(f"Loading resource '{self.key}' from {target_path}...")
#     175     try:
#
# File ~/Code/Projects/PerturbLab/perturblab/core/resource.py:137, in Resource.path(self)
#     135 # 2. Remote resolution
#     136 if self._remote_config:
# --> 137     remote_path = self._resolve_remote()
#     139     # Validate downloaded file
#     140     if not self._check_file(remote_path):
#
# File ~/Code/Projects/PerturbLab/perturblab/core/resource.py:289, in Resource._resolve_remote(self)
#     286     self._fetch_remote(self._remote_config, temp_path)
#     288 # Atomic get or create
# --> 289 return self._cache_manager.get_or_create(
#     290     key=cache_key,
#     291     create_fn=_download_callback,
#     292     is_directory=self._is_dir,
#     293     metadata=self._remote_config,
#     294 )
#
# File ~/Code/Projects/PerturbLab/perturblab/io/cache/_manager.py:339, in CacheManager.get_or_create(self, key, create_fn, force, is_directory, metadata)
#     336 try:
#     337     # Execute creation function
#     338     start_time = time.time()
# --> 339     create_fn(tmp_path)
#     340     elapsed = time.time() - start_time
#     342     # Calculate size (handle both files and directories)
#
# File ~/Code/Projects/PerturbLab/perturblab/core/resource.py:286, in Resource._resolve_remote.<locals>._download_callback(temp_path)
#     284 def _download_callback(temp_path: Path):
#     285     logger.info(f"Downloading remote resource '{self.key}'...")
# --> 286     self._fetch_remote(self._remote_config, temp_path)
#
# File ~/Code/Projects/PerturbLab/perturblab/data/resources/_type.py:317, in h5adFile._fetch_remote(self, config, target_path)
#     314 download_kwargs["target_path"] = target_path
#     316 logger.debug(f"Downloading h5ad with {downloader_name}...")
# --> 317 downloader_cls.download(**download_kwargs)
#
# File ~/Code/Projects/PerturbLab/perturblab/io/download/_http.py:178, in HTTPDownloader.download(url, target_path, resume, show_progress, chunk_size, timeout, max_retries, backoff_factor)
#     175     return target_path
#     177 except requests.RequestException as e:
# --> 178     raise DownloadError(f"Failed to download from {url}: {e}")
#     179 except Exception as e:
#     180     raise DownloadError(f"Download error: {e}")
#
# DownloadError: Failed to download from https://zenodo.org/record/13350497/files/NormanWeissman2019.h5ad?download=1: 404 Client Error: NOT FOUND for url: https://zenodo.org/records/13350497/files/NormanWeissman2019.h5ad

# %% [markdown]
# ## Download Gene Ontology File

# %%
# Download GO ontology file
go_path = load_dataset('go/go_basic')
print(f"GO file downloaded to: {go_path}")

# Check file size
import os
file_size_mb = os.path.getsize(go_path) / (1024 * 1024)
print(f"File size: {file_size_mb:.2f} MB")

# Second call uses cache (instant)
go_path_2 = load_dataset('go/go_basic')
print(f"\nCached path (same): {go_path == go_path_2}")
# Out:
# [perturblab] [INFO] Loading resource 'go_basic' from /home/wzq/.cache/perturblab/auto/go_basic...
# GO file downloaded to: /home/wzq/.cache/perturblab/auto/go_basic
# File size: 29.96 MB
#
# Cached path (same): True

# %% [markdown]
# ## Get Dataset Resource Metadata

# %%
# Get resource object for metadata
resource = get_dataset('scperturb/norman_2019')
print(f"Resource key: {resource.key}")
print(f"Resource type: {type(resource).__name__}")
print(f"Has remote config: {resource._remote_config is not None}")

if resource._remote_config:
    print(f"Downloader: {resource._remote_config.get('downloader', 'N/A')}")
# Out:
# Resource key: norman_2019
# Resource type: h5adFile
# Has remote config: True
# Downloader: HTTPDownloader
